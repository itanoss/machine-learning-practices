# %% [markdown]
# Hypothesis for prediction
# -----
# `H(x) = Wx + b`
#
# Cost function
# -----
# - How fit the line to our (training) data
#
# `cost(W) = (1/m) * sum(W - y_i)^2`

# %%
import tensorflow as tf

x_data = [1, 2, 3]
y_data = [1, 2, 3]

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

hypothesis = W * x_data + b

cost = tf.reduce_mean(tf.square(hypothesis - y_data))

a = tf.Variable(0.1)
optimizer = tf.train.GradientDescentOptimizer(a)
train = optimizer.minimize(cost)

init = tf.initialize_all_variables()

sess = tf.Session()
sess.run(init)

for step in xrange(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# (0, 0.049399961, array([ 1.13017309], dtype=float32), array([-0.06514558], dtype=float32))
# (20, 0.00057014631, array([ 1.02773249], dtype=float32), array([-0.06304237], dtype=float32))
# (40, 0.0002154156, array([ 1.01704645], dtype=float32), array([-0.03875066], dtype=float32))
# (60, 8.1390703e-05, array([ 1.01047814], dtype=float32), array([-0.02381916], dtype=float32))
# (80, 3.0751806e-05, array([ 1.00644064], dtype=float32), array([-0.01464112], dtype=float32))
# (100, 1.1618664e-05, array([ 1.00395894], dtype=float32), array([-0.00899943], dtype=float32))
# (120, 4.3898613e-06, array([ 1.00243342], dtype=float32), array([-0.00553175], dtype=float32))
# (140, 1.6585419e-06, array([ 1.00149572], dtype=float32), array([-0.00340018], dtype=float32))
# (160, 6.2660814e-07, array([ 1.00091934], dtype=float32), array([-0.00209], dtype=float32))
# (180, 2.3675324e-07, array([ 1.00056505], dtype=float32), array([-0.00128464], dtype=float32))
# (200, 8.9450886e-08, array([ 1.00034738], dtype=float32), array([-0.00078962], dtype=float32))
# (220, 3.3778161e-08, array([ 1.0002135], dtype=float32), array([-0.00048537], dtype=float32))
# (240, 1.278697e-08, array([ 1.00013125], dtype=float32), array([-0.00029836], dtype=float32))
# (260, 4.8209849e-09, array([ 1.00008059], dtype=float32), array([-0.00018334], dtype=float32))
# (280, 1.8181083e-09, array([ 1.00004959], dtype=float32), array([-0.00011268], dtype=float32))
# (300, 6.8677269e-10, array([ 1.00003052], dtype=float32), array([ -6.92887988e-05], dtype=float32))
# (320, 2.6115879e-10, array([ 1.00001872], dtype=float32), array([ -4.26455081e-05], dtype=float32))
# (340, 9.8600829e-11, array([ 1.00001156], dtype=float32), array([ -2.61469413e-05], dtype=float32))
# (360, 3.6835719e-11, array([ 1.00000703], dtype=float32), array([ -1.61651496e-05], dtype=float32))
# (380, 1.4429939e-11, array([ 1.00000441], dtype=float32), array([ -9.95434584e-06], dtype=float32))
# (400, 5.2355156e-12, array([ 1.00000274], dtype=float32), array([ -6.03633407e-06], dtype=float32))
# (420, 1.9670192e-12, array([ 1.00000167], dtype=float32), array([ -3.75148988e-06], dtype=float32))
# (440, 8.3370349e-13, array([ 1.00000095], dtype=float32), array([ -2.38058283e-06], dtype=float32))
# (460, 3.6119255e-13, array([ 1.0000006], dtype=float32), array([ -1.46664513e-06], dtype=float32))
# (480, 1.7171449e-13, array([ 1.00000048], dtype=float32), array([ -9.85833935e-07], dtype=float32))
# (500, 4.8553755e-14, array([ 1.00000036], dtype=float32), array([ -6.79863490e-07], dtype=float32))
# (520, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (540, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (560, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (580, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (600, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (620, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (640, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (660, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (680, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (700, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (720, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (740, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (760, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (780, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (800, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (820, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (840, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (860, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (880, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (900, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (920, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (940, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (960, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (980, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1000, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1020, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1040, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1060, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1080, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1100, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1120, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1140, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1160, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1180, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1200, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1220, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1240, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1260, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1280, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1300, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1320, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1340, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1360, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1380, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1400, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1420, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1440, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1460, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1480, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1500, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1520, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1540, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1560, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1580, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1600, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1620, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1640, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1660, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1680, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1700, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1720, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1740, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1760, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1780, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1800, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1820, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1840, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1860, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1880, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1900, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1920, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1940, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1960, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (1980, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))
# (2000, 3.7895614e-14, array([ 1.00000036], dtype=float32), array([ -6.24232541e-07], dtype=float32))

# %% [markdown]
# Using placeholder
# =====

# %%
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

hypothesis = W * X + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

a = tf.Variable(0.1)
optimizer = tf.train.GradientDescentOptimizer(a)
train = optimizer.minimize(cost)

init = tf.initialize_all_variables()

sess = tf.Session()
sess.run(init)

for step in xrange(2001):
    sess.run(train, feed_dict={X:x_data, Y:y_data})
    if step % 20 == 0:
        print(step, sess.run(cost, feed_dict={X:x_data, Y:y_data}), sess.run(W), sess.run(b))
# Out:
# (0, 0.033734694, array([ 0.94172043], dtype=float32), array([ 0.29395801], dtype=float32))
# (20, 0.0038864966, array([ 0.92759395], dtype=float32), array([ 0.16459602], dtype=float32))
# (40, 0.0014684213, array([ 0.95549369], dtype=float32), array([ 0.1011733], dtype=float32))
# (60, 0.00055480609, array([ 0.97264302], dtype=float32), array([ 0.0621888], dtype=float32))
# (80, 0.00020962297, array([ 0.98318428], dtype=float32), array([ 0.038226], dtype=float32))
# (100, 7.9200858e-05, array([ 0.98966384], dtype=float32), array([ 0.02349659], dtype=float32))
# (120, 2.9924451e-05, array([ 0.99364656], dtype=float32), array([ 0.01444278], dtype=float32))
# (140, 1.1306336e-05, array([ 0.99609464], dtype=float32), array([ 0.0088776], dtype=float32))
# (160, 4.2717429e-06, array([ 0.99759948], dtype=float32), array([ 0.00545686], dtype=float32))
# (180, 1.6139152e-06, array([ 0.99852449], dtype=float32), array([ 0.00335423], dtype=float32))
# (200, 6.0983371e-07, array([ 0.999093], dtype=float32), array([ 0.00206171], dtype=float32))
# (220, 2.3042143e-07, array([ 0.99944252], dtype=float32), array([ 0.0012673], dtype=float32))
# (240, 8.7072259e-08, array([ 0.99965733], dtype=float32), array([ 0.00077896], dtype=float32))
# (260, 3.2869618e-08, array([ 0.99978936], dtype=float32), array([ 0.00047878], dtype=float32))
# (280, 1.2422357e-08, array([ 0.99987054], dtype=float32), array([ 0.00029433], dtype=float32))
# (300, 4.6982032e-09, array([ 0.99992037], dtype=float32), array([ 0.00018091], dtype=float32))
# (320, 1.7764895e-09, array([ 0.99995106], dtype=float32), array([ 0.0001112], dtype=float32))
# (340, 6.7126393e-10, array([ 0.99996996], dtype=float32), array([  6.83686230e-05], dtype=float32))
# (360, 2.5375377e-10, array([ 0.99998146], dtype=float32), array([  4.20392680e-05], dtype=float32))
# (380, 9.576695e-11, array([ 0.99998862], dtype=float32), array([  2.58585915e-05], dtype=float32))
# (400, 3.6213994e-11, array([ 0.99999303], dtype=float32), array([  1.58926941e-05], dtype=float32))
# (420, 1.3699264e-11, array([ 0.99999571], dtype=float32), array([  9.80507230e-06], dtype=float32))
# (440, 5.0969597e-12, array([ 0.99999738], dtype=float32), array([  5.99037639e-06], dtype=float32))
# (460, 1.9137285e-12, array([ 0.99999839], dtype=float32), array([  3.70155817e-06], dtype=float32))
# (480, 7.6264922e-13, array([ 0.99999899], dtype=float32), array([  2.27104715e-06], dtype=float32))
# (500, 2.4632149e-13, array([ 0.99999934], dtype=float32), array([  1.39684607e-06], dtype=float32))
# (520, 9.4739029e-14, array([ 0.99999958], dtype=float32), array([  8.56431086e-07], dtype=float32))
# (540, 6.1580373e-14, array([ 0.99999964], dtype=float32), array([  6.65696405e-07], dtype=float32))
# (560, 6.1580373e-14, array([ 0.99999976], dtype=float32), array([  5.38539894e-07], dtype=float32))
# (580, 3.7895614e-14, array([ 0.99999994], dtype=float32), array([  2.84226644e-07], dtype=float32))
# (600, 4.2632564e-14, array([ 1.], dtype=float32), array([  1.33228127e-07], dtype=float32))
# (620, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (640, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (660, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (680, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (700, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (720, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (740, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (760, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (780, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (800, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (820, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (840, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (860, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (880, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (900, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (920, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (940, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (960, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (980, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1000, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1020, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1040, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1060, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1080, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1100, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1120, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1140, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1160, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1180, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1200, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1220, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1240, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1260, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1280, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1300, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1320, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1340, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1360, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1380, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1400, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1420, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1440, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1460, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1480, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1500, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1520, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1540, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1560, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1580, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1600, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1620, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1640, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1660, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1680, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1700, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1720, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1740, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1760, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1780, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1800, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1820, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1840, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1860, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1880, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1900, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1920, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1940, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1960, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (1980, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))
# (2000, 0.0, array([ 1.], dtype=float32), array([  5.37552651e-08], dtype=float32))

# %%
print(sess.run(hypothesis, feed_dict={X:10}))
# Out:
# [ 10.]

# %%
print(sess.run(hypothesis, feed_dict={X:32}))
# Out:
# [ 32.]
