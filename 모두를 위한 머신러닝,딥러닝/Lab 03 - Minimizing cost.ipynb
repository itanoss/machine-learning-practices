# %% [markdown]
# Simplified hypothesis
# -----
# `H(x) = Wx`
#
# `cost(x) = 1/m{sum((W_x_i - y_i)^2)}`
#
# Gradient Descent Algorithm
# =====
# `W := W - alpha * derivative(cost(W))`
#
# `cost(x) = 1/2m{sum((W_x_i - y_i)^2)}`
#
# `W := W - alpha / m * sum( (W_x_i - y_i) * x_i )`

# %%
import tensorflow as tf

X = [1., 2., 3.]
Y = [1., 2., 3.]

m = n_samples = len(X)

W = tf.placeholder(tf.float32)
hypothesis = tf.mul(X, W)

cost = tf.reduce_sum(tf.pow(hypothesis - Y, 2)) / m

init = tf.initialize_all_variables()

W_val = []
cost_val = []

sess = tf.Session()
sess.run(init)
for i in range(-30, 50):
    curr = i*0.1
    print curr, sess.run(cost, feed_dict={W: curr})
    W_val.append(curr)
    cost_val.append(sess.run(cost, feed_dict={W: curr}))
# Out:
# -3.0 74.6667
# -2.9 70.98
# -2.8 67.3867
# -2.7 63.8867
# -2.6 60.48
# -2.5 57.1667
# -2.4 53.9467
# -2.3 50.82
# -2.2 47.7867
# -2.1 44.8467
# -2.0 42.0
# -1.9 39.2467
# -1.8 36.5867
# -1.7 34.02
# -1.6 31.5467
# -1.5 29.1667
# -1.4 26.88
# -1.3 24.6867
# -1.2 22.5867
# -1.1 20.58
# -1.0 18.6667
# -0.9 16.8467
# -0.8 15.12
# -0.7 13.4867
# -0.6 11.9467
# -0.5 10.5
# -0.4 9.14667
# -0.3 7.88667
# -0.2 6.72
# -0.1 5.64667
# 0.0 4.66667
# 0.1 3.78
# 0.2 2.98667
# 0.3 2.28667
# 0.4 1.68
# 0.5 1.16667
# 0.6 0.746667
# 0.7 0.42
# 0.8 0.186667
# 0.9 0.0466667
# 1.0 0.0
# 1.1 0.0466667
# 1.2 0.186667
# 1.3 0.42
# 1.4 0.746666
# 1.5 1.16667
# 1.6 1.68
# 1.7 2.28667
# 1.8 2.98667
# 1.9 3.78
# 2.0 4.66667
# 2.1 5.64667
# 2.2 6.72
# 2.3 7.88667
# 2.4 9.14667
# 2.5 10.5
# 2.6 11.9467
# 2.7 13.4867
# 2.8 15.12
# 2.9 16.8467
# 3.0 18.6667
# 3.1 20.58
# 3.2 22.5867
# 3.3 24.6867
# 3.4 26.88
# 3.5 29.1667
# 3.6 31.5467
# 3.7 34.02
# 3.8 36.5867
# 3.9 39.2467
# 4.0 42.0
# 4.1 44.8467
# 4.2 47.7867
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(W_val, cost_val, 'ro')
plt.ylabel('Cost')
plt.xlabel('W')
plt.show()

# %%
x_data = [1., 2., 3.]
y_data = [1., 2., 3.]

W = tf.Variable(tf.random_uniform([1], -10., 10.))

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

hypothesis = W * X

# Simplified cost function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
alpha = 0.1
descent = W - tf.mul(alpha, tf.reduce_mean(tf.mul(tf.mul(W, X) - Y, X)))
update = W.assign(descent)

init = tf.initialize_all_variables()

sess = tf.Session()
sess.run(init)

for step in xrange(100):
    sess.run(update, feed_dict={X:x_data, Y:y_data})
    print step, sess.run(cost, feed_dict={X:x_data, Y:y_data}), sess.run(W)
# Out:
# 0 4.81097 [-0.01534319]
# 1 1.36845 [ 0.45848361]
# 2 0.389249 [ 0.7111913]
# 3 0.11072 [ 0.84596872]
# 4 0.0314936 [ 0.91785002]
# 5 0.00895819 [ 0.95618665]
# 6 0.0025481 [ 0.97663289]
# 7 0.000724792 [ 0.98753756]
# 8 0.000206163 [ 0.99335337]
# 9 5.86421e-05 [ 0.99645513]
# 10 1.66802e-05 [ 0.9981094]
# 11 4.74487e-06 [ 0.99899167]
# 12 1.34937e-06 [ 0.99946225]
# 13 3.839e-07 [ 0.99971318]
# 14 1.09128e-07 [ 0.99984705]
# 15 3.10821e-08 [ 0.9999184]
# 16 8.8455e-09 [ 0.99995649]
# 17 2.51157e-09 [ 0.99997681]
# 18 7.08938e-10 [ 0.99998766]
# 19 1.99051e-10 [ 0.99999344]
# 20 5.72946e-11 [ 0.99999648]
# 21 1.69772e-11 [ 0.99999809]
# 22 4.9134e-12 [ 0.99999899]
# 23 1.40806e-12 [ 0.99999946]
# 24 4.51195e-13 [ 0.9999997]
# 25 1.29082e-13 [ 0.99999982]
# 26 9.9476e-14 [ 0.99999988]
# 27 2.4869e-14 [ 0.99999994]
# 28 0.0 [ 1.]
# 29 0.0 [ 1.]
# 30 0.0 [ 1.]
# 31 0.0 [ 1.]
# 32 0.0 [ 1.]
# 33 0.0 [ 1.]
# 34 0.0 [ 1.]
# 35 0.0 [ 1.]
# 36 0.0 [ 1.]
# 37 0.0 [ 1.]
# 38 0.0 [ 1.]
# ...
